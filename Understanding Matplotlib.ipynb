# %%
from matplotlib import pyplot as plt
plt.plot([1,2,3],[4,5,1])
plt.show()

# %%
#Adding title and axis names
from matplotlib import pyplot as plt
x=[1,2,3]
y=[5,6,1]
plt.plot(x,y)
plt.title('Line Graph')
plt.xlabel('X Cordinates')
plt.ylabel('Y Cordinates')
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style

# %%
style.use('ggplot')

# %%
x=[1,2,3]
y=[5,4,1]
plt.plot(x,y,'b',label='line',linewidth=6,color="m")
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph')
plt.legend()
plt.grid(True,color='m')
plt.show()

# %%
from matplotlib import pyplot as plt
x=["Maths","English","Science"]
y=[19,18,20]
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
plt.hist([1,3,5,6,7],[6,8,9,4,2],label="Example-one",histtype='bar',rwidth=0.8)
plt.show()
plt.legend()
plt.xlabel('bar number')
plt.ylabel('yahoo')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-fef2273cda22> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.hist([1,3,5,6,7],[6,8,9,4,2],label="Example-one",histtype='bar',rwidth=0.8)
#       3 plt.show()
#       4 plt.legend()
#       5 plt.xlabel('bar number')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2683         orientation='vertical', rwidth=None, log=False, color=None,
#    2684         label=None, stacked=False, *, data=None, **kwargs):
# -> 2685     return gca().hist(
#    2686         x, bins=bins, range=range, density=density, weights=weights,
#    2687         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ...

# %%
plt.title("practise makes you perfect")
plt.xlabel("numbers1")
plt.ylabel('numbers2')
# Out:
# Text(0, 0.5, 'numbers2')

# %%
import matplotlib.pyplot as plt
population_ages=[10,20,30,40]
bins=[0,10,20,50]
plt.hist(population_ages,bins,histtype='bar',rwidth=0.8,color='m')
plt.xlabel('numbers1')
plt.ylabel('numbers2')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
population_ages=[10,20,30,40]
bins=[0,10,20,50]
plt.scatter[x,y,label='skitscat',color='k']
# Out:
#   File "<ipython-input-20-7f76cbe97067>", line 4
#     plt.scatter[x,y,label='skitscat',color='k']
#                          ^
# SyntaxError: invalid syntax

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import style

# %%
style.use('ggplot')

# %%
x=[5,18,20]
y=[6,15,27]
x1=[7,8,30]
x2=[9,34,20]
plt.plot(x,y,'g',label='label1',linewidth=5)
plt.plot(x1,x2,'r',label=['label2',linewidth=6)
plt.show()
# Out:
#   File "<ipython-input-27-c15c4d5185d5>", line 6
#     plt.plot(x1,x2,'r',label=['label2',linewidth=6)
#                                                 ^
# SyntaxError: invalid syntax
